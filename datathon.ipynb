# %%
import pandas as pd
import psycopg2 as ps
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import itertools
from matplotlib.lines import Line2D
from matplotlib.dates import YearLocator, DateFormatter
from datetime import datetime
from datetime import timedelta
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import r2_score
import warnings
import os
import joblib

warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('assets/csv/PEDE_PASSOS_DATASET_FIAP.csv', sep=';')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1349 entries, 0 to 1348
# Data columns (total 69 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   INSTITUICAO_ENSINO_ALUNO_2020  728 non-null    object
#  1   NOME                           1349 non-null   object
#  2   IDADE_ALUNO_2020               728 non-null    object
#  3   ANOS_PM_2020                   728 non-null    object
#  4   FASE_TURMA_2020                728 non-null    object
#  5   PONTO_VIRADA_2020              702 non-null    object
#  6   INDE_2020                      728 non-null    object
#  7   INDE_CONCEITO_2020             728 non-null    object
#  8   PEDRA_2020                     728 non-null    object
#  9   DESTAQUE_IEG_2020              728 non-null    object
#  10  DESTAQUE_IDA_2020              728 non-null    object
#  11  DESTAQUE_IPV_2020              703 non-null    object
#  12  IAA_2020                       728 non-null    object
#  13  IEG_2020                       728 non-null    object
#  14  IPS_2020                       728 non-null    object
#  15  IDA_2020                       728 non-null    object
#  16  IPP_2020                       728 non-null    object
#  17  IPV_2020                       728 non-null    object
#  18  IAN_2020                       728 non-null    object
#  19  FASE_2021                      686 non-null    float64
#  20  TURMA_2021                     686 non-null    object
#  21  INSTITUICAO_ENSINO_ALUNO_2021  686 non-null    object
#  22  SINALIZADOR_INGRESSANTE_2021   686 non-null    object
#  23  PEDRA_2021                     686 non-null    object
#  24  INDE_2021                      686 non-null    object
#  25  IAA_2021                       686 non-null    float64
#  26  IEG_2021                       686 non-null    float64
#  27  IPS_2021                       686 non-null    float64
#  28  IDA_2021                       686 non-null    float64
#  29  IPP_2021                       686 non-null    float64
#  30  REC_EQUIPE_1_2021              686 non-null    object
#  31  REC_EQUIPE_2_2021              686 non-null    object
#  32  REC_EQUIPE_3_2021              686 non-null    object
#  33  REC_EQUIPE_4_2021              686 non-null    object
#  34  PONTO_VIRADA_2021              686 non-null    object
#  35  IPV_2021                       686 non-null    float64
#  36  IAN_2021                       686 non-null    float64
#  37  NIVEL_IDEAL_2021               686 non-null    object
#  38  DEFASAGEM_2021                 686 non-null    float64
#  39  FASE_2022                      862 non-null    float64
#  40  TURMA_2022                     862 non-null    object
#  41  ANO_INGRESSO_2022              862 non-null    float64
#  42  BOLSISTA_2022                  862 non-null    object
#  43  INDE_2022                      862 non-null    float64
#  44  CG_2022                        862 non-null    float64
#  45  CF_2022                        862 non-null    float64
#  46  CT_2022                        862 non-null    float64
#  47  PEDRA_2022                     862 non-null    object
#  48  DESTAQUE_IEG_2022              862 non-null    object
#  49  DESTAQUE_IDA_2022              862 non-null    object
#  50  DESTAQUE_IPV_2022              862 non-null    object
#  51  IAA_2022                       862 non-null    float64
#  52  IEG_2022                       862 non-null    float64
#  53  IPS_2022                       862 non-null    float64
#  54  IDA_2022                       862 non-null    float64
#  55  NOTA_PORT_2022                 860 non-null    float64
#  56  NOTA_MAT_2022                  860 non-null    float64
#  57  NOTA_ING_2022                  285 non-null    float64
#  58  QTD_AVAL_2022                  862 non-null    float64
#  59  IPP_2022                       862 non-null    float64
#  60  REC_AVA_1_2022                 862 non-null    object
#  61  REC_AVA_2_2022                 862 non-null    object
#  62  REC_AVA_3_2022                 626 non-null    object
#  63  REC_AVA_4_2022                 285 non-null    object
#  64  INDICADO_BOLSA_2022            862 non-null    object
#  65  PONTO_VIRADA_2022              862 non-null    object
#  66  IPV_2022                       862 non-null    float64
#  67  IAN_2022                       862 non-null    float64
#  68  NIVEL_IDEAL_2022               862 non-null    object
# dtypes: float64(26), object(43)
# memory usage: 727.3+ KB

# %%
def filter_columns(df, filters: list): # adiciono no array o padrão que existe nas colunas e que não quero que tenha na saída final
    selected_columns = [True] * len(df.columns)  # Inicializa todas as colunas como True
    for index, column in enumerate(df.columns):
        if any(filter in column for filter in filters): selected_columns[index] = False
    return df[df.columns[selected_columns]]

# %%
def cleaning_dataset(df):
  _df = df.dropna(subset=df.columns.difference(['NOME']), how='all') # executa o dropna para todas as colunas sem visualizar a coluna NOME
  _df = _df[~_df.isna().all(axis=1)] # remove linhas com apenas NaN, se tiver algum dado na linha não remove
  return _df

# %%
# Função para extrair o valor numérico da string
def extrair_numero(valor):
    # Encontrar todos os números na string e retornar o primeiro encontrado
    numeros = re.findall(r'\d+', str(valor))
    if numeros:
        return int(numeros[0])
    else:
        return None

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1349 entries, 0 to 1348
# Data columns (total 69 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   INSTITUICAO_ENSINO_ALUNO_2020  728 non-null    object
#  1   NOME                           1349 non-null   object
#  2   IDADE_ALUNO_2020               728 non-null    object
#  3   ANOS_PM_2020                   728 non-null    object
#  4   FASE_TURMA_2020                728 non-null    object
#  5   PONTO_VIRADA_2020              702 non-null    object
#  6   INDE_2020                      728 non-null    object
#  7   INDE_CONCEITO_2020             728 non-null    object
#  8   PEDRA_2020                     728 non-null    object
#  9   DESTAQUE_IEG_2020              728 non-null    object
#  10  DESTAQUE_IDA_2020              728 non-null    object
#  11  DESTAQUE_IPV_2020              703 non-null    object
#  12  IAA_2020                       728 non-null    object
#  13  IEG_2020                       728 non-null    object
#  14  IPS_2020                       728 non-null    object
#  15  IDA_2020                       728 non-null    object
#  16  IPP_2020                       728 non-null    object
#  17  IPV_2020                       728 non-null    object
#  18  IAN_2020                       728 non-null    object
#  19  FASE_2021                      686 non-null    float64
#  20  TURMA_2021                     686 non-null    object
#  21  INSTITUICAO_ENSINO_ALUNO_2021  686 non-null    object
#  22  SINALIZADOR_INGRESSANTE_2021   686 non-null    object
#  23  PEDRA_2021                     686 non-null    object
#  24  INDE_2021                      686 non-null    object
#  25  IAA_2021                       686 non-null    float64
#  26  IEG_2021                       686 non-null    float64
#  27  IPS_2021                       686 non-null    float64
#  28  IDA_2021                       686 non-null    float64
#  29  IPP_2021                       686 non-null    float64
#  30  REC_EQUIPE_1_2021              686 non-null    object
#  31  REC_EQUIPE_2_2021              686 non-null    object
#  32  REC_EQUIPE_3_2021              686 non-null    object
#  33  REC_EQUIPE_4_2021              686 non-null    object
#  34  PONTO_VIRADA_2021              686 non-null    object
#  35  IPV_2021                       686 non-null    float64
#  36  IAN_2021                       686 non-null    float64
#  37  NIVEL_IDEAL_2021               686 non-null    object
#  38  DEFASAGEM_2021                 686 non-null    float64
#  39  FASE_2022                      862 non-null    float64
#  40  TURMA_2022                     862 non-null    object
#  41  ANO_INGRESSO_2022              862 non-null    float64
#  42  BOLSISTA_2022                  862 non-null    object
#  43  INDE_2022                      862 non-null    float64
#  44  CG_2022                        862 non-null    float64
#  45  CF_2022                        862 non-null    float64
#  46  CT_2022                        862 non-null    float64
#  47  PEDRA_2022                     862 non-null    object
#  48  DESTAQUE_IEG_2022              862 non-null    object
#  49  DESTAQUE_IDA_2022              862 non-null    object
#  50  DESTAQUE_IPV_2022              862 non-null    object
#  51  IAA_2022                       862 non-null    float64
#  52  IEG_2022                       862 non-null    float64
#  53  IPS_2022                       862 non-null    float64
#  54  IDA_2022                       862 non-null    float64
#  55  NOTA_PORT_2022                 860 non-null    float64
#  56  NOTA_MAT_2022                  860 non-null    float64
#  57  NOTA_ING_2022                  285 non-null    float64
#  58  QTD_AVAL_2022                  862 non-null    float64
#  59  IPP_2022                       862 non-null    float64
#  60  REC_AVA_1_2022                 862 non-null    object
#  61  REC_AVA_2_2022                 862 non-null    object
#  62  REC_AVA_3_2022                 626 non-null    object
#  63  REC_AVA_4_2022                 285 non-null    object
#  64  INDICADO_BOLSA_2022            862 non-null    object
#  65  PONTO_VIRADA_2022              862 non-null    object
#  66  IPV_2022                       862 non-null    float64
#  67  IAN_2022                       862 non-null    float64
#  68  NIVEL_IDEAL_2022               862 non-null    object
# dtypes: float64(26), object(43)
# memory usage: 727.3+ KB

# %%
df = df.round(2)

# %%
print(df.dtypes)
# Out:
# INSTITUICAO_ENSINO_ALUNO_2020     object
# NOME                              object
# IDADE_ALUNO_2020                  object
# ANOS_PM_2020                      object
# FASE_TURMA_2020                   object
#                                   ...
# INDICADO_BOLSA_2022               object
# PONTO_VIRADA_2022                 object
# IPV_2022                         float64
# IAN_2022                         float64
# NIVEL_IDEAL_2022                  object
# Length: 69, dtype: object

# %%
# Filtrando 2020
df_2020 = filter_columns(df, ['2021', '2022'])

# Filtrando 2021
df_2021 = filter_columns(df, ['2020', '2022'])

# Filtrando 2022
df_2022 = filter_columns(df, ['2020', '2021'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1349 entries, 0 to 1348
# Data columns (total 69 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   INSTITUICAO_ENSINO_ALUNO_2020  728 non-null    object
#  1   NOME                           1349 non-null   object
#  2   IDADE_ALUNO_2020               728 non-null    object
#  3   ANOS_PM_2020                   728 non-null    object
#  4   FASE_TURMA_2020                728 non-null    object
#  5   PONTO_VIRADA_2020              702 non-null    object
#  6   INDE_2020                      728 non-null    object
#  7   INDE_CONCEITO_2020             728 non-null    object
#  8   PEDRA_2020                     728 non-null    object
#  9   DESTAQUE_IEG_2020              728 non-null    object
#  10  DESTAQUE_IDA_2020              728 non-null    object
#  11  DESTAQUE_IPV_2020              703 non-null    object
#  12  IAA_2020                       728 non-null    object
#  13  IEG_2020                       728 non-null    object
#  14  IPS_2020                       728 non-null    object
#  15  IDA_2020                       728 non-null    object
#  16  IPP_2020                       728 non-null    object
#  17  IPV_2020                       728 non-null    object
#  18  IAN_2020                       728 non-null    object
#  19  FASE_2021                      686 non-null    float64
#  20  TURMA_2021                     686 non-null    object
#  21  INSTITUICAO_ENSINO_ALUNO_2021  686 non-null    object
#  22  SINALIZADOR_INGRESSANTE_2021   686 non-null    object
#  23  PEDRA_2021                     686 non-null    object
#  24  INDE_2021                      686 non-null    object
#  25  IAA_2021                       686 non-null    float64
#  26  IEG_2021                       686 non-null    float64
#  27  IPS_2021                       686 non-null    float64
#  28  IDA_2021                       686 non-null    float64
#  29  IPP_2021                       686 non-null    float64
#  30  REC_EQUIPE_1_2021              686 non-null    object
#  31  REC_EQUIPE_2_2021              686 non-null    object
#  32  REC_EQUIPE_3_2021              686 non-null    object
#  33  REC_EQUIPE_4_2021              686 non-null    object
#  34  PONTO_VIRADA_2021              686 non-null    object
#  35  IPV_2021                       686 non-null    float64
#  36  IAN_2021                       686 non-null    float64
#  37  NIVEL_IDEAL_2021               686 non-null    object
#  38  DEFASAGEM_2021                 686 non-null    float64
#  39  FASE_2022                      862 non-null    float64
#  40  TURMA_2022                     862 non-null    object
#  41  ANO_INGRESSO_2022              862 non-null    float64
#  42  BOLSISTA_2022                  862 non-null    object
#  43  INDE_2022                      862 non-null    float64
#  44  CG_2022                        862 non-null    float64
#  45  CF_2022                        862 non-null    float64
#  46  CT_2022                        862 non-null    float64
#  47  PEDRA_2022                     862 non-null    object
#  48  DESTAQUE_IEG_2022              862 non-null    object
#  49  DESTAQUE_IDA_2022              862 non-null    object
#  50  DESTAQUE_IPV_2022              862 non-null    object
#  51  IAA_2022                       862 non-null    float64
#  52  IEG_2022                       862 non-null    float64
#  53  IPS_2022                       862 non-null    float64
#  54  IDA_2022                       862 non-null    float64
#  55  NOTA_PORT_2022                 860 non-null    float64
#  56  NOTA_MAT_2022                  860 non-null    float64
#  57  NOTA_ING_2022                  285 non-null    float64
#  58  QTD_AVAL_2022                  862 non-null    float64
#  59  IPP_2022                       862 non-null    float64
#  60  REC_AVA_1_2022                 862 non-null    object
#  61  REC_AVA_2_2022                 862 non-null    object
#  62  REC_AVA_3_2022                 626 non-null    object
#  63  REC_AVA_4_2022                 285 non-null    object
#  64  INDICADO_BOLSA_2022            862 non-null    object
#  65  PONTO_VIRADA_2022              862 non-null    object
#  66  IPV_2022                       862 non-null    float64
#  67  IAN_2022                       862 non-null    float64
#  68  NIVEL_IDEAL_2022               862 non-null    object
# dtypes: float64(26), object(43)
# memory usage: 727.3+ KB

# %%
# Analisando a idade dos alunos

df_idade = df
df_idade['IDADE_ALUNO_2020'] = pd.to_numeric(df['IDADE_ALUNO_2020'], errors='coerce')
df_idade['IDADE_ALUNO_2020'] = df['IDADE_ALUNO_2020'].fillna(0).astype(int)
df_idade = df.dropna(subset=['IDADE_ALUNO_2020'])
df_idade = df[df['IDADE_ALUNO_2020'] > 0]

# %%
df_idade.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 727 entries, 0 to 1347
# Data columns (total 69 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   INSTITUICAO_ENSINO_ALUNO_2020  727 non-null    object
#  1   NOME                           727 non-null    object
#  2   IDADE_ALUNO_2020               727 non-null    int32
#  3   ANOS_PM_2020                   727 non-null    object
#  4   FASE_TURMA_2020                727 non-null    object
#  5   PONTO_VIRADA_2020              701 non-null    object
#  6   INDE_2020                      727 non-null    object
#  7   INDE_CONCEITO_2020             727 non-null    object
#  8   PEDRA_2020                     727 non-null    object
#  9   DESTAQUE_IEG_2020              727 non-null    object
#  10  DESTAQUE_IDA_2020              727 non-null    object
#  11  DESTAQUE_IPV_2020              703 non-null    object
#  12  IAA_2020                       727 non-null    object
#  13  IEG_2020                       727 non-null    object
#  14  IPS_2020                       727 non-null    object
#  15  IDA_2020                       727 non-null    object
#  16  IPP_2020                       727 non-null    object
#  17  IPV_2020                       727 non-null    object
#  18  IAN_2020                       727 non-null    object
#  19  FASE_2021                      457 non-null    float64
#  20  TURMA_2021                     457 non-null    object
#  21  INSTITUICAO_ENSINO_ALUNO_2021  457 non-null    object
#  22  SINALIZADOR_INGRESSANTE_2021   457 non-null    object
#  23  PEDRA_2021                     457 non-null    object
#  24  INDE_2021                      457 non-null    object
#  25  IAA_2021                       457 non-null    float64
#  26  IEG_2021                       457 non-null    float64
#  27  IPS_2021                       457 non-null    float64
#  28  IDA_2021                       457 non-null    float64
#  29  IPP_2021                       457 non-null    float64
#  30  REC_EQUIPE_1_2021              457 non-null    object
#  31  REC_EQUIPE_2_2021              457 non-null    object
#  32  REC_EQUIPE_3_2021              457 non-null    object
#  33  REC_EQUIPE_4_2021              457 non-null    object
#  34  PONTO_VIRADA_2021              457 non-null    object
#  35  IPV_2021                       457 non-null    float64
#  36  IAN_2021                       457 non-null    float64
#  37  NIVEL_IDEAL_2021               457 non-null    object
#  38  DEFASAGEM_2021                 457 non-null    float64
#  39  FASE_2022                      327 non-null    float64
#  40  TURMA_2022                     327 non-null    object
#  41  ANO_INGRESSO_2022              327 non-null    float64
#  42  BOLSISTA_2022                  327 non-null    object
#  43  INDE_2022                      327 non-null    float64
#  44  CG_2022                        327 non-null    float64
#  45  CF_2022                        327 non-null    float64
#  46  CT_2022                        327 non-null    float64
#  47  PEDRA_2022                     327 non-null    object
#  48  DESTAQUE_IEG_2022              327 non-null    object
#  49  DESTAQUE_IDA_2022              327 non-null    object
#  50  DESTAQUE_IPV_2022              327 non-null    object
#  51  IAA_2022                       327 non-null    float64
#  52  IEG_2022                       327 non-null    float64
#  53  IPS_2022                       327 non-null    float64
#  54  IDA_2022                       327 non-null    float64
#  55  NOTA_PORT_2022                 327 non-null    float64
#  56  NOTA_MAT_2022                  327 non-null    float64
#  57  NOTA_ING_2022                  168 non-null    float64
#  58  QTD_AVAL_2022                  327 non-null    float64
#  59  IPP_2022                       327 non-null    float64
#  60  REC_AVA_1_2022                 327 non-null    object
#  61  REC_AVA_2_2022                 327 non-null    object
#  62  REC_AVA_3_2022                 301 non-null    object
#  63  REC_AVA_4_2022                 157 non-null    object
#  64  INDICADO_BOLSA_2022            327 non-null    object
#  65  PONTO_VIRADA_2022              327 non-null    object
#  66  IPV_2022                       327 non-null    float64
#  67  IAN_2022                       327 non-null    float64
#  68  NIVEL_IDEAL_2022               327 non-null    object
# dtypes: float64(26), int32(1), object(42)
# memory usage: 394.7+ KB

# %%
# Desvendando os dados sobre a idade dos alunos

idade_media = df_idade['IDADE_ALUNO_2020'].mean()
idade_mediana = df_idade['IDADE_ALUNO_2020'].median()
idade_variancia = df_idade['IDADE_ALUNO_2020'].var()
idade_desvio_padrao = df_idade['IDADE_ALUNO_2020'].std()
idade_moda = df_idade['IDADE_ALUNO_2020'].mode()[0]

print(f"Média: {idade_media}")
print(f"Mediana: {idade_mediana}")
print(f"Desvio Padrão: {idade_desvio_padrao}")
print(f"Variância: {idade_variancia}")
print(f"Moda: {idade_moda}")
# Out:
# Média: 12.408528198074277
# Mediana: 12.0
# Desvio Padrão: 2.829806699677048
# Variância: 8.007805957537107
# Moda: 10

# %%
idade_counts = df_idade['IDADE_ALUNO_2020'].value_counts().sort_index()

# Distribuição de idade dos alunos

plt.figure(figsize=(10, 6))
idade_counts.plot(kind='bar', color='skyblue', edgecolor = 'black')
plt.xlabel('Idade do Aluno')
plt.ylabel('Quantidade de Alunos')
plt.title('Quantidade de Alunos por Idade (2020)')
plt.xticks(rotation=45)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %%
df_fase = df.dropna(subset=['FASE_TURMA_2020'])

# Função para extrair apenas o número da fase (ignora a letra)
df_fase['Fase_Numero'] = df_fase['FASE_TURMA_2020'].str.extract(r'(\d+)')

# Remover os valores onde a fase é '207'
df_fase = df_fase[df_fase['Fase_Numero'] != '207']

# Contar a quantidade de alunos por fase (apenas pelo número)
contagem_fases = df_fase['Fase_Numero'].value_counts().sort_index()

# Plotar o gráfico de barras
plt.figure(figsize=(10, 6))
bars = contagem_fases.plot(kind='bar', color='skyblue', edgecolor = 'black')

# Adicionar títulos e rótulos
plt.title('Quantidade de Alunos por Fase')
plt.xlabel('Fase')
plt.ylabel('Quantidade de Alunos')
plt.xticks(rotation=45)
for idx, valor in enumerate(contagem_fases):
    bars.text(idx, valor + 1, str(valor), ha='center', va='bottom')
    
plt.show()

# %%
# Distribuição das instituições de ensino dos alunos

df_instituicao = df.dropna(subset=['INSTITUICAO_ENSINO_ALUNO_2020'])

# Contar a quantidade de alunos por tipo de instituição

df_instituicao['Tipo_Instituicao'] = df_instituicao['INSTITUICAO_ENSINO_ALUNO_2020'].apply(
    lambda x: 'Pública' if 'Pública' in str(x) else 'Privada')

# Contar a quantidade de alunos em cada tipo de instituição
contagem_tipo_instituicao = df_instituicao['Tipo_Instituicao'].value_counts()

# Filtrar apenas instituições privadas
instituicoes_privadas = df_instituicao[df_instituicao['Tipo_Instituicao'] == 'Privada']
contagem_instituicoes_privadas = instituicoes_privadas['INSTITUICAO_ENSINO_ALUNO_2020'].value_counts()

# Gráfico de distribuição por tipo de instituição

plt.figure(figsize=(18, 6))
plt.subplot(1, 2, 1)
plt.bar(contagem_tipo_instituicao.index, contagem_tipo_instituicao.values, color=['skyblue', 'lightgreen'], edgecolor='black')
plt.xlabel('Tipo de Instituição')
plt.ylabel('Número de Alunos')
plt.title('Distribuição por Tipo de Instituição')
plt.grid(axis='y', linestyle='--', alpha=0.7)

# %%
# Gráfico de distribuição de instituições privadas (se houver)

plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 2)
plt.bar(contagem_instituicoes_privadas.index, contagem_instituicoes_privadas.values, color='skyblue', edgecolor='black')
plt.xlabel('Nome da Instituição Privada')
plt.ylabel('Número de Alunos')
plt.title('Distribuição de Instituições Privadas')
plt.xticks(rotation=45)
plt.grid(axis='y', linestyle='--', alpha=0.7)

plt.tight_layout()
plt.show()

# %%
# Verificando e tratando os alunos que atingiram o ponto de virada em 2020.

colunas_ponto_virada = df[['PONTO_VIRADA_2020','PONTO_VIRADA_2021','PONTO_VIRADA_2022']]

ponto_atingido = ['Sim']

# Contar ocorrências para cada ano
contagem_por_ano = {col: colunas_ponto_virada[col].value_counts() for col in colunas_ponto_virada.columns}

# Exibir os resultados
for ano, contagem in contagem_por_ano.items():
    print(f"\nContagem de alunos que atingiram o {ano}:")
    print(contagem)
# Out:
# Contagem de alunos que atingiram o PONTO_VIRADA_2020:
# PONTO_VIRADA_2020
# Não      607
# Sim       94
# D9600      1
# Name: count, dtype: int64
#
# Contagem de alunos que atingiram o PONTO_VIRADA_2021:
# PONTO_VIRADA_2021
# Não       576
# Sim       108
# #NULO!      2
# Name: count, dtype: int64
#
# Contagem de alunos que atingiram o PONTO_VIRADA_2022:
# PONTO_VIRADA_2022
# Não    749
# Sim    113
# Name: count, dtype: int64

# %%
contagem_2020 = colunas_ponto_virada['PONTO_VIRADA_2020'].value_counts().get(ponto_atingido, 0)
contagem_2021 = colunas_ponto_virada['PONTO_VIRADA_2021'].value_counts().get(ponto_atingido, 0)
contagem_2022 = colunas_ponto_virada['PONTO_VIRADA_2022'].value_counts().get(ponto_atingido, 0)

# Crie uma lista com os valores de contagem
contagens = [int(contagem_2020), int(contagem_2021), int(contagem_2022)]

# Anos para o eixo X
anos = ['2020', '2021', '2022']

# Plote o gráfico
plt.figure(figsize=(12, 6))
plt.plot(anos, contagens, marker='o', linestyle='-', color='blue')
plt.xlabel('Ano')
plt.ylabel('Número de Alunos')
plt.title('Evolução da quantidade de Alunos que Atingiram o Ponto de Virada')
plt.grid(True)
plt.xticks(anos)

for idx, valor in enumerate(contagens):
    plt.annotate(str(valor), (anos[idx], valor), textcoords="offset points", xytext=(0,5), ha='center')

plt.show()

# %%
# Verificando e tratando a média INDE.

df_inde = df[['NOME', 'INDE_2020', 'INDE_2021', 'INDE_2022']]
print(df_inde)
# Out:
#             NOME          INDE_2020 INDE_2021  INDE_2022
# 0        ALUNO-1           7.883752     7.319        NaN
# 1        ALUNO-2                NaN       NaN       7.68
# 2        ALUNO-3  7.856389666666666     7.021        NaN
# 3        ALUNO-4           5.076252       NaN       7.12
# 4        ALUNO-5           8.077085     7.399       7.23
# ...          ...                ...       ...        ...
# 1344  ALUNO-1345                NaN     6.606        NaN
# 1345  ALUNO-1346                NaN       NaN       8.14
# 1346  ALUNO-1347  7.158543333333334       NaN        NaN
# 1347  ALUNO-1348  7.842224333333333     7.422       6.75
# 1348  ALUNO-1349                NaN       NaN       6.40
#
# [1349 rows x 4 columns]

# %%
# Analisando média geral do INDE

for col in ['INDE_2020', 'INDE_2021', 'INDE_2022']:
    df_inde[col] = pd.to_numeric(df_inde[col], errors='coerce')

colunas_numericas = df_inde.select_dtypes(include='number')

df_inde.loc[:, colunas_numericas.columns] = colunas_numericas.fillna(colunas_numericas.mean())

media_inde = df_inde[['INDE_2020', 'INDE_2021', 'INDE_2022']].mean()
print(media_inde)
# Out:
# INDE_2020    7.296111
# INDE_2021    6.888016
# INDE_2022    7.028341
# dtype: float64

# %%
# Converter colunas de INDE para numérico, substituindo erros por NaN
df['INDE_2020'] = pd.to_numeric(df['INDE_2020'], errors='coerce')
df['INDE_2021'] = pd.to_numeric(df['INDE_2021'], errors='coerce')
df['INDE_2022'] = pd.to_numeric(df['INDE_2022'], errors='coerce')

# Dividir os alunos em dois grupos: atingiram (Sim) e não atingiram (Não) o ponto de virada
atingiu_pv = df[(df['PONTO_VIRADA_2020'] == 'Sim') | (df['PONTO_VIRADA_2021'] == 'Sim') | (df['PONTO_VIRADA_2022'] == 'Sim')]
nao_atingiu_pv = df[(df['PONTO_VIRADA_2020'] == 'Não') & (df['PONTO_VIRADA_2021'] == 'Não') & (df['PONTO_VIRADA_2022'] == 'Não')]

# Calcular a média de INDE para cada grupo
media_atingiu_pv = atingiu_pv[['INDE_2020', 'INDE_2021', 'INDE_2022']].mean()
media_nao_atingiu_pv = nao_atingiu_pv[['INDE_2020', 'INDE_2021', 'INDE_2022']].mean()

# Criar um gráfico para comparar as médias de INDE para os dois grupos
anos = ['INDE_2020', 'INDE_2021', 'INDE_2022']

plt.figure(figsize=(12,6))
plt.plot(anos, media_atingiu_pv, label='Atingiu Ponto de Virada', marker='o', color = 'blue')
plt.plot(anos, media_nao_atingiu_pv, label='Não Atingiu Ponto de Virada', marker='o', color = 'red')

# Adicionar título e rótulos aos eixos
plt.title('Comparando a variação da Média do INDE')
plt.xlabel('Ano')
plt.ylabel('Média do INDE')
plt.grid(True)
plt.legend()
plt.show()

# %%
# Classificando de acordo com as pedras

analise_pedra = df[['PEDRA_2020','PEDRA_2021','PEDRA_2022']]
tipos_desejados = ['Ametista', 'Ágata', 'Quartzo', 'Topázio']

# Contar ocorrências para cada ano
contagem_por_ano = {col: analise_pedra[col].value_counts() for col in analise_pedra.columns}

# Exibir os resultados
for ano, contagem in contagem_por_ano.items():
    print(f"\nContagem de tipos de pedra para {ano}:")
    print(contagem)
# Out:
# Contagem de tipos de pedra para PEDRA_2020:
# PEDRA_2020
# Ametista    336
# Ágata       171
# Quartzo     128
# Topázio      92
# D9891/2A      1
# Name: count, dtype: int64
#
# Contagem de tipos de pedra para PEDRA_2021:
# PEDRA_2021
# Ametista    295
# Ágata       178
# Quartzo     110
# Topázio     101
# #NULO!        2
# Name: count, dtype: int64
#
# Contagem de tipos de pedra para PEDRA_2022:
# PEDRA_2022
# Ametista    348
# Ágata       250
# Quartzo     134
# Topázio     130
# Name: count, dtype: int64

# %%
# Tipos de pedra que queremos analisar
tipos_desejados = ['Ametista', 'Ágata', 'Quartzo', 'Topázio']

# Filtrar o DataFrame para incluir apenas os tipos de pedra desejados
for col in analise_pedra.columns:
    analise_pedra[col] = analise_pedra[col].apply(lambda x: x if x in tipos_desejados else None)

# Contar ocorrências para cada ano
contagem_por_ano = {col: analise_pedra[col].value_counts() for col in analise_pedra.columns}

# Transformar o dicionário em DataFrame para facilitar a análise
contagem_df = pd.DataFrame(contagem_por_ano).fillna(0)

# Filtrar o DataFrame para incluir apenas as pedras desejadas
contagem_df = contagem_df.loc[tipos_desejados]

# Plotar a evolução da contagem das pedras ao longo dos anos
plt.figure(figsize=(12, 8))

# Plotar linhas para cada tipo de pedra
for pedra in contagem_df.index:
    plt.plot(contagem_df.columns, contagem_df.loc[pedra], marker='o', label=pedra)

# Adicionar detalhes ao gráfico
plt.xlabel('Ano')
plt.ylabel('Contagem')
plt.title('Evolução da Contagem de Tipos de Pedra ao Longo dos Anos')
plt.legend(title='Tipo de Pedra')
plt.grid(True)
plt.show()

# %%
# Verificando e tratando a média IDA.

df_ida = df[['NOME', 'IDA_2020', 'IDA_2021', 'IDA_2022']]
print(df_ida)
# Out:
#             NOME           IDA_2020  IDA_2021  IDA_2022
# 0        ALUNO-1                  7       8.8       NaN
# 1        ALUNO-2                NaN       NaN      8.82
# 2        ALUNO-3                5.5       5.6       NaN
# 3        ALUNO-4                  0       NaN      5.08
# 4        ALUNO-5                7.5       5.4      7.08
# ...          ...                ...       ...       ...
# 1344  ALUNO-1345                NaN       4.9       NaN
# 1345  ALUNO-1346                NaN       NaN      9.00
# 1346  ALUNO-1347  4.666666666666667       NaN       NaN
# 1347  ALUNO-1348  6.333333333333333       6.9      5.90
# 1348  ALUNO-1349                NaN       NaN      4.50
#
# [1349 rows x 4 columns]

# %%
# Analisando média geral do IDA

for col in ['IDA_2020', 'IDA_2021', 'IDA_2022']:
    df_ida[col] = pd.to_numeric(df_ida[col], errors='coerce')

colunas_numericas = df_ida.select_dtypes(include='number')

df_ida.loc[:, colunas_numericas.columns] = colunas_numericas.fillna(colunas_numericas.mean())

media_ida = df_ida[['IDA_2020', 'IDA_2021', 'IDA_2022']].mean()
print(media_ida)
# Out:
# IDA_2020    6.322260
# IDA_2021    5.425948
# IDA_2022    6.070812
# dtype: float64

# %%
# Converter colunas de IDA para numérico, substituindo erros por NaN
df['IDA_2020'] = pd.to_numeric(df['IDA_2020'], errors='coerce')
df['IDA_2021'] = pd.to_numeric(df['IDA_2021'], errors='coerce')
df['IDA_2022'] = pd.to_numeric(df['IDA_2022'], errors='coerce')

# Dividir os alunos em dois grupos: atingiram (Sim) e não atingiram (Não) o ponto de virada
atingiu_pv = df[(df['PONTO_VIRADA_2020'] == 'Sim') | (df['PONTO_VIRADA_2021'] == 'Sim') | (df['PONTO_VIRADA_2022'] == 'Sim')]
nao_atingiu_pv = df[(df['PONTO_VIRADA_2020'] == 'Não') & (df['PONTO_VIRADA_2021'] == 'Não') & (df['PONTO_VIRADA_2022'] == 'Não')]

# Calcular a média de IDA para cada grupo
media_atingiu_pv = atingiu_pv[['IDA_2020', 'IDA_2021', 'IDA_2022']].mean()
media_nao_atingiu_pv = nao_atingiu_pv[['IDA_2020', 'IDA_2021', 'IDA_2022']].mean()

# Criar um gráfico para comparar as médias de IDA para os dois grupos
anos = ['IDA_2020', 'IDA_2021', 'IDA_2022']

plt.figure(figsize=(12,6))
plt.plot(anos, media_atingiu_pv, label='Atingiu Ponto de Virada', marker='o', color = 'blue')
plt.plot(anos, media_nao_atingiu_pv, label='Não Atingiu Ponto de Virada', marker='o', color = 'red')

# Adicionar título e rótulos aos eixos
plt.title('Comparando a variação da Média do IDA')
plt.xlabel('Ano')
plt.ylabel('Média de IDA')
plt.grid(True)
plt.legend()
plt.show()

# %%
# Verificando e tratando a média IEG.

df_ieg = df[['NOME', 'IEG_2020', 'IEG_2021', 'IEG_2022']]
print(df_ieg)
# Out:
#             NOME IEG_2020  IEG_2021  IEG_2022
# 0        ALUNO-1      8.7       6.3       NaN
# 1        ALUNO-2      NaN       NaN      7.58
# 2        ALUNO-3      8.9       6.9       NaN
# 3        ALUNO-4      4.1       NaN      8.07
# 4        ALUNO-5        8       7.5      8.56
# ...          ...      ...       ...       ...
# 1344  ALUNO-1345      NaN       6.7       NaN
# 1345  ALUNO-1346      NaN       NaN      9.03
# 1346  ALUNO-1347      8.1       NaN       NaN
# 1347  ALUNO-1348      7.1       8.6      9.18
# 1348  ALUNO-1349      NaN       NaN      7.54
#
# [1349 rows x 4 columns]

# %%
# Analisando média geral do IEG

for col in ['IEG_2020', 'IEG_2021', 'IEG_2022']:
    df_ieg[col] = pd.to_numeric(df_ieg[col], errors='coerce')

colunas_numericas = df_ieg.select_dtypes(include='number')

df_ieg.loc[:, colunas_numericas.columns] = colunas_numericas.fillna(colunas_numericas.mean())

media_ieg = df_ieg[['IEG_2020', 'IEG_2021', 'IEG_2022']].mean()
print(media_ieg)
# Out:
# IEG_2020    7.681155
# IEG_2021    6.822595
# IEG_2022    7.880882
# dtype: float64

# %%
# Converter colunas de IEG para numérico, substituindo erros por NaN
df['IEG_2020'] = pd.to_numeric(df['IEG_2020'], errors='coerce')
df['IEG_2021'] = pd.to_numeric(df['IEG_2021'], errors='coerce')
df['IEG_2022'] = pd.to_numeric(df['IEG_2022'], errors='coerce')

# Dividir os alunos em dois grupos: atingiram (Sim) e não atingiram (Não) o ponto de virada
atingiu_pv = df[(df['PONTO_VIRADA_2020'] == 'Sim') | (df['PONTO_VIRADA_2021'] == 'Sim') | (df['PONTO_VIRADA_2022'] == 'Sim')]
nao_atingiu_pv = df[(df['PONTO_VIRADA_2020'] == 'Não') & (df['PONTO_VIRADA_2021'] == 'Não') & (df['PONTO_VIRADA_2022'] == 'Não')]

# Calcular a média de IEG para cada grupo
media_atingiu_pv = atingiu_pv[['IEG_2020', 'IEG_2021', 'IEG_2022']].mean()
media_nao_atingiu_pv = nao_atingiu_pv[['IEG_2020', 'IEG_2021', 'IEG_2022']].mean()

# Criar um gráfico para comparar as médias de IEG para os dois grupos
anos = ['IEG_2020', 'IEG_2021', 'IEG_2022']

plt.figure(figsize=(12,6))
plt.plot(anos, media_atingiu_pv, label='Atingiu Ponto de Virada', marker='o', color = 'blue')
plt.plot(anos, media_nao_atingiu_pv, label='Não Atingiu Ponto de Virada', marker='o', color = 'red')

# Adicionar título e rótulos aos eixos
plt.title('Comparando a variação da Média do IEG')
plt.xlabel('Ano')
plt.ylabel('Média de IEG')
plt.grid(True)
plt.legend()
plt.show()

# %%
# Verificando e tratando a média IAN.

df_ian = df[['NOME', 'IAN_2020', 'IAN_2021', 'IAN_2022']]
print(df_ian)
# Out:
#             NOME IAN_2020  IAN_2021  IAN_2022
# 0        ALUNO-1       10       5.0       NaN
# 1        ALUNO-2      NaN       NaN       5.0
# 2        ALUNO-3       10      10.0       NaN
# 3        ALUNO-4        5       NaN       5.0
# 4        ALUNO-5       10      10.0       5.0
# ...          ...      ...       ...       ...
# 1344  ALUNO-1345      NaN       5.0       NaN
# 1345  ALUNO-1346      NaN       NaN       5.0
# 1346  ALUNO-1347       10       NaN       NaN
# 1347  ALUNO-1348       10       5.0       5.0
# 1348  ALUNO-1349      NaN       NaN       5.0
#
# [1349 rows x 4 columns]

# %%
# Analisando média geral do IAN

for col in ['IAN_2020', 'IAN_2021', 'IAN_2022']:
    df_ian[col] = pd.to_numeric(df_ian[col], errors='coerce')

colunas_numericas = df_ian.select_dtypes(include='number')

df_ian.loc[:, colunas_numericas.columns] = colunas_numericas.fillna(colunas_numericas.mean())

media_ian = df_ian[['IAN_2020', 'IAN_2021', 'IAN_2022']].mean()
print(media_ian)
# Out:
# IAN_2020    7.431224
# IAN_2021    6.902332
# IAN_2022    6.421114
# dtype: float64

# %%
# Converter colunas de IAN para numérico, substituindo erros por NaN
df['IAN_2020'] = pd.to_numeric(df['IAN_2020'], errors='coerce')
df['IAN_2021'] = pd.to_numeric(df['IAN_2021'], errors='coerce')
df['IAN_2022'] = pd.to_numeric(df['IAN_2022'], errors='coerce')

# Dividir os alunos em dois grupos: atingiram (Sim) e não atingiram (Não) o ponto de virada
atingiu_pv = df[(df['PONTO_VIRADA_2020'] == 'Sim') | (df['PONTO_VIRADA_2021'] == 'Sim') | (df['PONTO_VIRADA_2022'] == 'Sim')]
nao_atingiu_pv = df[(df['PONTO_VIRADA_2020'] == 'Não') & (df['PONTO_VIRADA_2021'] == 'Não') & (df['PONTO_VIRADA_2022'] == 'Não')]

# Calcular a média de IAN para cada grupo
media_atingiu_pv = atingiu_pv[['IAN_2020', 'IAN_2021', 'IAN_2022']].mean()
media_nao_atingiu_pv = nao_atingiu_pv[['IAN_2020', 'IAN_2021', 'IAN_2022']].mean()

# Criar um gráfico para comparar as médias de IAN para os dois grupos
anos = ['IAN_2020', 'IAN_2021', 'IAN_2022']

plt.figure(figsize=(12,6))
plt.plot(anos, media_atingiu_pv, label='Atingiu Ponto de Virada', marker='o', color = 'blue')
plt.plot(anos, media_nao_atingiu_pv, label='Não Atingiu Ponto de Virada', marker='o', color = 'red')

# Adicionar título e rótulos aos eixos
plt.title('Comparando a variação da Média do IAN')
plt.xlabel('Ano')
plt.ylabel('Média de IAN')
plt.grid(True)
plt.legend()
plt.show()

# %%
# Verificando e tratando a média IAA.

df_iaa = df[['NOME', 'IAA_2020', 'IAA_2021', 'IAA_2022']]
print(df_iaa)
# Out:
#             NOME           IAA_2020  IAA_2021  IAA_2022
# 0        ALUNO-1  8.500020000000001       7.5       NaN
# 1        ALUNO-2                NaN       NaN     10.00
# 2        ALUNO-3            7.91667       7.1       NaN
# 3        ALUNO-4  8.000020000000001       NaN     10.00
# 4        ALUNO-5            7.50002       7.4      6.42
# ...          ...                ...       ...       ...
# 1344  ALUNO-1345                NaN       9.0       NaN
# 1345  ALUNO-1346                NaN       NaN      9.00
# 1346  ALUNO-1347            9.16668       NaN       NaN
# 1347  ALUNO-1348            7.91667       7.5      8.33
# 1348  ALUNO-1349                NaN       NaN      7.92
#
# [1349 rows x 4 columns]

# %%
# Analisando média geral do IAA

for col in ['IAA_2020', 'IAA_2021', 'IAA_2022']:
    df_iaa[col] = pd.to_numeric(df_iaa[col], errors='coerce')

colunas_numericas = df_iaa.select_dtypes(include='number')

df_iaa.loc[:, colunas_numericas.columns] = colunas_numericas.fillna(colunas_numericas.mean())

media_iaa = df_iaa[['IAA_2020', 'IAA_2021', 'IAA_2022']].mean()
print(media_iaa)
# Out:
# IAA_2020    8.368882
# IAA_2021    8.153499
# IAA_2022    8.263248
# dtype: float64

# %%
# Converter colunas de IAA para numérico, substituindo erros por NaN
df['IAA_2020'] = pd.to_numeric(df['IAA_2020'], errors='coerce')
df['IAA_2021'] = pd.to_numeric(df['IAA_2021'], errors='coerce')
df['IAA_2022'] = pd.to_numeric(df['IAA_2022'], errors='coerce')

# Dividir os alunos em dois grupos: atingiram (Sim) e não atingiram (Não) o ponto de virada
atingiu_pv = df[(df['PONTO_VIRADA_2020'] == 'Sim') | (df['PONTO_VIRADA_2021'] == 'Sim') | (df['PONTO_VIRADA_2022'] == 'Sim')]
nao_atingiu_pv = df[(df['PONTO_VIRADA_2020'] == 'Não') & (df['PONTO_VIRADA_2021'] == 'Não') & (df['PONTO_VIRADA_2022'] == 'Não')]

# Calcular a média de IAA para cada grupo
media_atingiu_pv = atingiu_pv[['IAA_2020', 'IAA_2021', 'IAA_2022']].mean()
media_nao_atingiu_pv = nao_atingiu_pv[['IAA_2020', 'IAA_2021', 'IAA_2022']].mean()

# Criar um gráfico para comparar as médias de IAN para os dois grupos
anos = ['IAA_2020', 'IAA_2021', 'IAA_2022']

plt.figure(figsize=(12,6))
plt.plot(anos, media_atingiu_pv, label='Atingiu Ponto de Virada', marker='o', color = 'blue')
plt.plot(anos, media_nao_atingiu_pv, label='Não Atingiu Ponto de Virada', marker='o', color = 'red')

# Adicionar título e rótulos aos eixos
plt.title('Comparando a variação da Média do IAA')
plt.xlabel('Ano')
plt.ylabel('Média de IAA')
plt.grid(True)
plt.legend()
plt.show()

# %%
# Verificando e tratando a média IPS.

df_ips = df[['NOME', 'IPS_2020', 'IPS_2021', 'IPS_2022']]
print(df_ips)
# Out:
#             NOME IPS_2020  IPS_2021  IPS_2022
# 0        ALUNO-1      7.5       6.9       NaN
# 1        ALUNO-2      NaN       NaN      7.50
# 2        ALUNO-3      7.5       6.3       NaN
# 3        ALUNO-4    6.875       NaN      7.50
# 4        ALUNO-5      7.5       7.5      7.50
# ...          ...      ...       ...       ...
# 1344  ALUNO-1345      NaN       7.5       NaN
# 1345  ALUNO-1346      NaN       NaN      7.50
# 1346  ALUNO-1347    6.875       NaN       NaN
# 1347  ALUNO-1348    6.875       6.3      5.62
# 1348  ALUNO-1349      NaN       NaN      7.50
#
# [1349 rows x 4 columns]

# %%
# Analisando média geral do IPS

for col in ['IPS_2020', 'IPS_2021', 'IPS_2022']:
    df_ips[col] = pd.to_numeric(df_ips[col], errors='coerce')

colunas_numericas = df_ips.select_dtypes(include='number')

df_ips.loc[:, colunas_numericas.columns] = colunas_numericas.fillna(colunas_numericas.mean())

media_ips = df_ips[['IPS_2020', 'IPS_2021', 'IPS_2022']].mean()
print(media_ips)
# Out:
# IPS_2020    6.737448
# IPS_2021    6.843586
# IPS_2022    6.900766
# dtype: float64

# %%
# Converter colunas de IPS para numérico, substituindo erros por NaN
df['IPS_2020'] = pd.to_numeric(df['IPS_2020'], errors='coerce')
df['IPS_2021'] = pd.to_numeric(df['IPS_2021'], errors='coerce')
df['IPS_2022'] = pd.to_numeric(df['IPS_2022'], errors='coerce')

# Dividir os alunos em dois grupos: atingiram (Sim) e não atingiram (Não) o ponto de virada
atingiu_pv = df[(df['PONTO_VIRADA_2020'] == 'Sim') | (df['PONTO_VIRADA_2021'] == 'Sim') | (df['PONTO_VIRADA_2022'] == 'Sim')]
nao_atingiu_pv = df[(df['PONTO_VIRADA_2020'] == 'Não') & (df['PONTO_VIRADA_2021'] == 'Não') & (df['PONTO_VIRADA_2022'] == 'Não')]

# Calcular a média de IPS para cada grupo
media_atingiu_pv = atingiu_pv[['IPS_2020', 'IPS_2021', 'IPS_2022']].mean()
media_nao_atingiu_pv = nao_atingiu_pv[['IPS_2020', 'IPS_2021', 'IPS_2022']].mean()

# Criar um gráfico para comparar as médias de IAN para os dois grupos
anos = ['IPS_2020', 'IPS_2021', 'IPS_2022']

plt.figure(figsize=(12,6))
plt.plot(anos, media_atingiu_pv, label='Atingiu Ponto de Virada', marker='o', color = 'blue')
plt.plot(anos, media_nao_atingiu_pv, label='Não Atingiu Ponto de Virada', marker='o', color = 'red')

# Adicionar título e rótulos aos eixos
plt.title('Comparando a variação da Média do IPS')
plt.xlabel('Ano')
plt.ylabel('Média de IPS')
plt.grid(True)
plt.legend()
plt.show()

# %%
# Verificando e tratando a média IPP.

df_ipp = df[['NOME', 'IPP_2020', 'IPP_2021', 'IPP_2022']]
print(df_ipp)
# Out:
#             NOME           IPP_2020  IPP_2021  IPP_2022
# 0        ALUNO-1             5.9375       7.7       NaN
# 1        ALUNO-2                NaN       NaN      5.62
# 2        ALUNO-3              8.125       7.3       NaN
# 3        ALUNO-4             7.1875       NaN      6.25
# 4        ALUNO-5             8.4375       8.5      6.46
# ...          ...                ...       ...       ...
# 1344  ALUNO-1345                NaN       7.2       NaN
# 1345  ALUNO-1346                NaN       NaN      5.62
# 1346  ALUNO-1347            7.34375       NaN       NaN
# 1347  ALUNO-1348  8.541666666666666       7.5      6.72
# 1348  ALUNO-1349                NaN       NaN      7.50
#
# [1349 rows x 4 columns]

# %%
# Analisando média geral do IPP

for col in ['IPP_2020', 'IPP_2021', 'IPP_2022']:
    df_ipp[col] = pd.to_numeric(df_ipp[col], errors='coerce')

colunas_numericas = df_ipp.select_dtypes(include='number')

df_ipp.loc[:, colunas_numericas.columns] = colunas_numericas.fillna(colunas_numericas.mean())

media_ipp = df_ipp[['IPP_2020', 'IPP_2021', 'IPP_2022']].mean()
print(media_ipp)
# Out:
# IPP_2020    7.067859
# IPP_2021    7.576385
# IPP_2022    6.298480
# dtype: float64

# %%
# Converter colunas de IPP para numérico, substituindo erros por NaN
df['IPP_2020'] = pd.to_numeric(df['IPP_2020'], errors='coerce')
df['IPP_2021'] = pd.to_numeric(df['IPP_2021'], errors='coerce')
df['IPP_2022'] = pd.to_numeric(df['IPP_2022'], errors='coerce')

# Dividir os alunos em dois grupos: atingiram (Sim) e não atingiram (Não) o ponto de virada
atingiu_pv = df[(df['PONTO_VIRADA_2020'] == 'Sim') | (df['PONTO_VIRADA_2021'] == 'Sim') | (df['PONTO_VIRADA_2022'] == 'Sim')]
nao_atingiu_pv = df[(df['PONTO_VIRADA_2020'] == 'Não') & (df['PONTO_VIRADA_2021'] == 'Não') & (df['PONTO_VIRADA_2022'] == 'Não')]

# Calcular a média de IPP para cada grupo
media_atingiu_pv = atingiu_pv[['IPP_2020', 'IPP_2021', 'IPP_2022']].mean()
media_nao_atingiu_pv = nao_atingiu_pv[['IPP_2020', 'IPP_2021', 'IPP_2022']].mean()

# Criar um gráfico para comparar as médias de IAN para os dois grupos
anos = ['IPP_2020', 'IPP_2021', 'IPP_2022']

plt.figure(figsize=(12,6))
plt.plot(anos, media_atingiu_pv, label='Atingiu Ponto de Virada', marker='o', color = 'blue')
plt.plot(anos, media_nao_atingiu_pv, label='Não Atingiu Ponto de Virada', marker='o', color = 'red')

# Adicionar título e rótulos aos eixos
plt.title('Comparando a variação da Média do IPP')
plt.xlabel('Ano')
plt.ylabel('Média de IPP')
plt.grid(True)
plt.legend()
plt.show()

# %%
# Verificando e tratando a média IPV.

df_ipv = df[['NOME', 'IPV_2020', 'IPV_2021', 'IPV_2022']]
print(df_ipv)
# Out:
#             NOME           IPV_2020  IPV_2021  IPV_2022
# 0        ALUNO-1               7.75       8.1       NaN
# 1        ALUNO-2                NaN       NaN      7.92
# 2        ALUNO-3  8.111113333333334       7.2       NaN
# 3        ALUNO-4               7.75       NaN      8.06
# 4        ALUNO-5           8.166665       7.4      7.83
# ...          ...                ...       ...       ...
# 1344  ALUNO-1345                NaN       7.1       NaN
# 1345  ALUNO-1346                NaN       NaN      9.08
# 1346  ALUNO-1347           6.333335       NaN       NaN
# 1347  ALUNO-1348            9.11112       8.5      5.83
# 1348  ALUNO-1349                NaN       NaN      6.00
#
# [1349 rows x 4 columns]

# %%
# Analisando média geral do IPV

for col in ['IPV_2020', 'IPV_2021', 'IPV_2022']:
    df_ipv[col] = pd.to_numeric(df_ipv[col], errors='coerce')

colunas_numericas = df_ipv.select_dtypes(include='number')

df_ipv.loc[:, colunas_numericas.columns] = colunas_numericas.fillna(colunas_numericas.mean())

media_ipv = df_ipv[['IPV_2020', 'IPV_2021', 'IPV_2022']].mean()
print(media_ipv)
# Out:
# IPV_2020    7.242243
# IPV_2021    7.407580
# IPV_2022    7.247981
# dtype: float64

# %%
# Converter colunas de IPV para numérico, substituindo erros por NaN
df['IPV_2020'] = pd.to_numeric(df['IPV_2020'], errors='coerce')
df['IPV_2021'] = pd.to_numeric(df['IPV_2021'], errors='coerce')
df['IPV_2022'] = pd.to_numeric(df['IPV_2022'], errors='coerce')

# Dividir os alunos em dois grupos: atingiram (Sim) e não atingiram (Não) o ponto de virada
atingiu_pv = df[(df['PONTO_VIRADA_2020'] == 'Sim') | (df['PONTO_VIRADA_2021'] == 'Sim') | (df['PONTO_VIRADA_2022'] == 'Sim')]
nao_atingiu_pv = df[(df['PONTO_VIRADA_2020'] == 'Não') & (df['PONTO_VIRADA_2021'] == 'Não') & (df['PONTO_VIRADA_2022'] == 'Não')]

# Calcular a média de IPV para cada grupo
media_atingiu_pv = atingiu_pv[['IPV_2020', 'IPV_2021', 'IPV_2022']].mean()
media_nao_atingiu_pv = nao_atingiu_pv[['IPV_2020', 'IPV_2021', 'IPV_2022']].mean()

# Criar um gráfico para comparar as médias de IAN para os dois grupos
anos = ['IPV_2020', 'IPV_2021', 'IPV_2022']

plt.figure(figsize=(12,6))
plt.plot(anos, media_atingiu_pv, label='Atingiu Ponto de Virada', marker='o', color = 'blue')
plt.plot(anos, media_nao_atingiu_pv, label='Não Atingiu Ponto de Virada', marker='o', color = 'red')

# Adicionar título e rótulos aos eixos
plt.title('Comparando a variação da Média do IPV')
plt.xlabel('Ano')
plt.ylabel('Média de IPV')
plt.grid(True)
plt.legend()
plt.show()

# %%
df.dropna(subset=['IPV_2020', 'IPV_2021', 'IPV_2022'], inplace=True)

# %%
# Criando o modelo de previsão para entender quais os alunos irão atingir o Ponto de virada em 2023

# 1. Preparar os dados
features = df[['IPV_2020', 'IPV_2021', 'IPV_2022']]
target = df['IPV_2022']  # Utilizando a coluna IPV_2022 como alvo para prever o próximo ano

# Dividir os dados em conjunto de treinamento e teste
X_train, X_test, y_train, y_test = train_test_split(features, target, test_size=0.2, random_state=42)

# 2. Treinamento do modelo
model = RandomForestRegressor(n_estimators=100, random_state=42)
model.fit(X_train, y_train)

# 3. Prever o IPV para 2023
ipvs_previstos_2023 = model.predict(features)  # Prever baseado nas mesmas features

# 4. Calcular as notas de corte para 2020, 2021, 2022 e 2023
media_2020 = df['IPV_2020'].mean()
media_2021 = df['IPV_2021'].mean()
media_2022 = df['IPV_2022'].mean()
media_2023 = ipvs_previstos_2023.mean()

desvio_2020 = df['IPV_2020'].std()
desvio_2021 = df['IPV_2021'].std()
desvio_2022 = df['IPV_2022'].std()
desvio_2023 = ipvs_previstos_2023.std()

nota_corte_2020 = media_2020 + desvio_2020
nota_corte_2021 = media_2021 + desvio_2021
nota_corte_2022 = media_2022 + desvio_2022
nota_corte_2023 = media_2023 + desvio_2023

# 5. Determinar se os alunos atingirão o ponto de virada
resultados = []
for ipv in ipvs_previstos_2023:
    if ipv > nota_corte_2023:
        resultados.append("Sim")
    else:
        resultados.append("Não")

# Criar um DataFrame com os resultados
resultado_df = pd.DataFrame({
    'Aluno': [f'Aluno {i + 1}' for i in range(len(resultados))],
    'IPV Previsto': ipvs_previstos_2023,
    'Atingirá o ponto de virada': resultados
})

# Exibir os resultados
for idx, resultado in enumerate(resultados):
    print(f"Aluno {idx + 1}: IPV Previsto = {ipvs_previstos_2023[idx]:.2f}, Atingirá o ponto de virada: {resultado}")

# Exibir notas de corte
print(f"Nota de corte para 2020: {nota_corte_2020:.2f}")
print(f"Nota de corte para 2021: {nota_corte_2021:.2f}")
print(f"Nota de corte para 2022: {nota_corte_2022:.2f}")
print(f"Nota de corte para 2023: {nota_corte_2023:.2f}")
# Out:
# Aluno 1: IPV Previsto = 7.83, Atingirá o ponto de virada: Não
# Aluno 2: IPV Previsto = 7.62, Atingirá o ponto de virada: Não
# Aluno 3: IPV Previsto = 9.50, Atingirá o ponto de virada: Sim
# Aluno 4: IPV Previsto = 7.50, Atingirá o ponto de virada: Não
# Aluno 5: IPV Previsto = 7.25, Atingirá o ponto de virada: Não
# Aluno 6: IPV Previsto = 6.39, Atingirá o ponto de virada: Não
# Aluno 7: IPV Previsto = 7.79, Atingirá o ponto de virada: Não
# Aluno 8: IPV Previsto = 7.78, Atingirá o ponto de virada: Não
# Aluno 9: IPV Previsto = 6.89, Atingirá o ponto de virada: Não
# Aluno 10: IPV Previsto = 6.92, Atingirá o ponto de virada: Não
# Aluno 11: IPV Previsto = 7.28, Atingirá o ponto de virada: Não
# Aluno 12: IPV Previsto = 7.40, Atingirá o ponto de virada: Não
# Aluno 13: IPV Previsto = 9.72, Atingirá o ponto de virada: Sim
# Aluno 14: IPV Previsto = 8.28, Atingirá o ponto de virada: Não
# Aluno 15: IPV Previsto = 7.83, Atingirá o ponto de virada: Não
# Aluno 16: IPV Previsto = 8.83, Atingirá o ponto de virada: Sim
# Aluno 17: IPV Previsto = 7.75, Atingirá o ponto de virada: Não
# Aluno 18: IPV Previsto = 8.44, Atingirá o ponto de virada: Não
# Aluno 19: IPV Previsto = 8.83, Atingirá o ponto de virada: Sim
# Aluno 20: IPV Previsto = 7.14, Atingirá o ponto de virada: Não
# Aluno 21: IPV Previsto = 9.10, Atingirá o ponto de virada: Sim
# Aluno 22: IPV Previsto = 6.89, Atingirá o ponto de virada: Não
# Aluno 23: IPV Previsto = 7.50, Atingirá o ponto de virada: Não
# Aluno 24: IPV Previsto = 5.56, Atingirá o ponto de virada: Não
# Aluno 25: IPV Previsto = 7.43, Atingirá o ponto de virada: Não
# Aluno 26: IPV Previsto = 7.83, Atingirá o ponto de virada: Não
# Aluno 27: IPV Previsto = 7.75, Atingirá o ponto de virada: Não
# Aluno 28: IPV Previsto = 5.42, Atingirá o ponto de virada: Não
# Aluno 29: IPV Previsto = 9.31, Atingirá o ponto de virada: Sim
# Aluno 30: IPV Previsto = 7.17, Atingirá o ponto de virada: Não
# Aluno 31: IPV Previsto = 7.57, Atingirá o ponto de virada: Não
# Aluno 32: IPV Previsto = 6.83, Atingirá o ponto de virada: Não
# Aluno 33: IPV Previsto = 8.12, Atingirá o ponto de virada: Não
# Aluno 34: IPV Previsto = 7.25, Atingirá o ponto de virada: Não
# Aluno 35: IPV Previsto = 9.29, Atingirá o ponto de virada: Sim
# Aluno 36: IPV Previsto = 6.00, Atingirá o ponto de virada: Não
# Aluno 37: IPV Previsto = 7.71, Atingirá o ponto de virada: Não
# Aluno 38: IPV Previsto = 6.50, Atingirá o ponto de virada: Não
# Aluno 39: IPV Previsto = 7.61, Atingirá o ponto de virada: Não
# Aluno 40: IPV Previsto = 8.39, Atingirá o ponto de virada: Não
# Aluno 41: IPV Previsto = 6.89, Atingirá o ponto de virada: Não
# Aluno 42: IPV Previsto = 8.00, Atingirá o ponto de virada: Não
# Aluno 43: IPV Previsto = 7.74, Atingirá o ponto de virada: Não
# Aluno 44: IPV Previsto = 8.46, Atingirá o ponto de virada: Não
# Aluno 45: IPV Previsto = 7.62, Atingirá o ponto de virada: Não
# Aluno 46: IPV Previsto = 7.94, Atingirá o ponto de virada: Não
# Aluno 47: IPV Previsto = 5.16, Atingirá o ponto de virada: Não
# Aluno 48: IPV Previsto = 8.90, Atingirá o ponto de virada: Sim
# Aluno 49: IPV Previsto = 6.61, Atingirá o ponto de virada: Não
# Aluno 50: IPV Previsto = 6.67, Atingirá o ponto de virada: Não
# Aluno 51: IPV Previsto = 5.83, Atingirá o ponto de virada: Não
# Aluno 52: IPV Previsto = 6.00, Atingirá o ponto de virada: Não
# Aluno 53: IPV Previsto = 4.81, Atingirá o ponto de virada: Não
# Aluno 54: IPV Previsto = 6.93, Atingirá o ponto de virada: Não
# Aluno 55: IPV Previsto = 7.50, Atingirá o ponto de virada: Não
# Aluno 56: IPV Previsto = 8.44, Atingirá o ponto de virada: Não
# Aluno 57: IPV Previsto = 6.78, Atingirá o ponto de virada: Não
# Aluno 58: IPV Previsto = 7.56, Atingirá o ponto de virada: Não
# Aluno 59: IPV Previsto = 8.39, Atingirá o ponto de virada: Não
# Aluno 60: IPV Previsto = 7.83, Atingirá o ponto de virada: Não
# Aluno 61: IPV Previsto = 7.56, Atingirá o ponto de virada: Não
# Aluno 62: IPV Previsto = 6.83, Atingirá o ponto de virada: Não
# Aluno 63: IPV Previsto = 7.94, Atingirá o ponto de virada: Não
# Aluno 64: IPV Previsto = 7.70, Atingirá o ponto de virada: Não
# Aluno 65: IPV Previsto = 4.66, Atingirá o ponto de virada: Não
# Aluno 66: IPV Previsto = 7.67, Atingirá o ponto de virada: Não
# Aluno 67: IPV Previsto = 7.50, Atingirá o ponto de virada: Não
# Aluno 68: IPV Previsto = 8.33, Atingirá o ponto de virada: Não
# Aluno 69: IPV Previsto = 7.07, Atingirá o ponto de virada: Não
# Aluno 70: IPV Previsto = 6.71, Atingirá o ponto de virada: Não
# Aluno 71: IPV Previsto = 7.33, Atingirá o ponto de virada: Não
# Aluno 72: IPV Previsto = 5.83, Atingirá o ponto de virada: Não
# Aluno 73: IPV Previsto = 8.16, Atingirá o ponto de virada: Não
# Aluno 74: IPV Previsto = 9.11, Atingirá o ponto de virada: Sim
# Aluno 75: IPV Previsto = 6.16, Atingirá o ponto de virada: Não
# Aluno 76: IPV Previsto = 8.45, Atingirá o ponto de virada: Não
# Aluno 77: IPV Previsto = 6.79, Atingirá o ponto de virada: Não
# Aluno 78: IPV Previsto = 6.93, Atingirá o ponto de virada: Não
# Aluno 79: IPV Previsto = 7.92, Atingirá o ponto de virada: Não
# Aluno 80: IPV Previsto = 5.79, Atingirá o ponto de virada: Não
# Aluno 81: IPV Previsto = 5.27, Atingirá o ponto de virada: Não
# Aluno 82: IPV Previsto = 8.58, Atingirá o ponto de virada: Sim
# Aluno 83: IPV Previsto = 6.13, Atingirá o ponto de virada: Não
# Aluno 84: IPV Previsto = 8.50, Atingirá o ponto de virada: Sim
# Aluno 85: IPV Previsto = 7.05, Atingirá o ponto de virada: Não
# Aluno 86: IPV Previsto = 7.39, Atingirá o ponto de virada: Não
# Aluno 87: IPV Previsto = 7.25, Atingirá o ponto de virada: Não
# Aluno 88: IPV Previsto = 4.80, Atingirá o ponto de virada: Não
# Aluno 89: IPV Previsto = 7.06, Atingirá o ponto de virada: Não
# Aluno 90: IPV Previsto = 7.79, Atingirá o ponto de virada: Não
# Aluno 91: IPV Previsto = 6.29, Atingirá o ponto de virada: Não
# Aluno 92: IPV Previsto = 9.09, Atingirá o ponto de virada: Sim
# Aluno 93: IPV Previsto = 7.83, Atingirá o ponto de virada: Não
# Aluno 94: IPV Previsto = 9.59, Atingirá o ponto de virada: Sim
# Aluno 95: IPV Previsto = 6.62, Atingirá o ponto de virada: Não
# Aluno 96: IPV Previsto = 4.48, Atingirá o ponto de virada: Não
# Aluno 97: IPV Previsto = 7.33, Atingirá o ponto de virada: Não
# Aluno 98: IPV Previsto = 6.67, Atingirá o ponto de virada: Não
# Aluno 99: IPV Previsto = 7.56, Atingirá o ponto de virada: Não
# Aluno 100: IPV Previsto = 6.04, Atingirá o ponto de virada: Não
# Aluno 101: IPV Previsto = 7.61, Atingirá o ponto de virada: Não
# Aluno 102: IPV Previsto = 8.49, Atingirá o ponto de virada: Sim
# Aluno 103: IPV Previsto = 8.06, Atingirá o ponto de virada: Não
# Aluno 104: IPV Previsto = 5.83, Atingirá o ponto de virada: Não
# Aluno 105: IPV Previsto = 7.78, Atingirá o ponto de virada: Não
# Aluno 106: IPV Previsto = 7.45, Atingirá o ponto de virada: Não
# Aluno 107: IPV Previsto = 7.88, Atingirá o ponto de virada: Não
# Aluno 108: IPV Previsto = 6.93, Atingirá o ponto de virada: Não
# Aluno 109: IPV Previsto = 6.61, Atingirá o ponto de virada: Não
# Aluno 110: IPV Previsto = 9.16, Atingirá o ponto de virada: Sim
# Aluno 111: IPV Previsto = 8.70, Atingirá o ponto de virada: Sim
# Aluno 112: IPV Previsto = 4.04, Atingirá o ponto de virada: Não
# Aluno 113: IPV Previsto = 7.42, Atingirá o ponto de virada: Não
# Aluno 114: IPV Previsto = 7.50, Atingirá o ponto de virada: Não
# Aluno 115: IPV Previsto = 8.50, Atingirá o ponto de virada: Sim
# Aluno 116: IPV Previsto = 7.79, Atingirá o ponto de virada: Não
# Aluno 117: IPV Previsto = 7.43, Atingirá o ponto de virada: Não
# Aluno 118: IPV Previsto = 6.37, Atingirá o ponto de virada: Não
# Aluno 119: IPV Previsto = 8.84, Atingirá o ponto de virada: Sim
# Aluno 120: IPV Previsto = 8.28, Atingirá o ponto de virada: Não
# Aluno 121: IPV Previsto = 7.50, Atingirá o ponto de virada: Não
# Aluno 122: IPV Previsto = 7.33, Atingirá o ponto de virada: Não
# Aluno 123: IPV Previsto = 8.94, Atingirá o ponto de virada: Sim
# Aluno 124: IPV Previsto = 7.67, Atingirá o ponto de virada: Não
# Aluno 125: IPV Previsto = 6.07, Atingirá o ponto de virada: Não
# Aluno 126: IPV Previsto = 6.11, Atingirá o ponto de virada: Não
# Aluno 127: IPV Previsto = 6.29, Atingirá o ponto de virada: Não
# Aluno 128: IPV Previsto = 5.83, Atingirá o ponto de virada: Não
# Aluno 129: IPV Previsto = 7.22, Atingirá o ponto de virada: Não
# Aluno 130: IPV Previsto = 6.58, Atingirá o ponto de virada: Não
# Aluno 131: IPV Previsto = 7.00, Atingirá o ponto de virada: Não
# Aluno 132: IPV Previsto = 7.89, Atingirá o ponto de virada: Não
# Aluno 133: IPV Previsto = 9.47, Atingirá o ponto de virada: Sim
# Aluno 134: IPV Previsto = 8.00, Atingirá o ponto de virada: Não
# Aluno 135: IPV Previsto = 5.95, Atingirá o ponto de virada: Não
# Aluno 136: IPV Previsto = 6.78, Atingirá o ponto de virada: Não
# Aluno 137: IPV Previsto = 7.50, Atingirá o ponto de virada: Não
# Aluno 138: IPV Previsto = 7.50, Atingirá o ponto de virada: Não
# Aluno 139: IPV Previsto = 8.57, Atingirá o ponto de virada: Sim
# Aluno 140: IPV Previsto = 6.83, Atingirá o ponto de virada: Não
# Aluno 141: IPV Previsto = 5.42, Atingirá o ponto de virada: Não
# Aluno 142: IPV Previsto = 6.50, Atingirá o ponto de virada: Não
# Aluno 143: IPV Previsto = 7.78, Atingirá o ponto de virada: Não
# Aluno 144: IPV Previsto = 9.08, Atingirá o ponto de virada: Sim
# Aluno 145: IPV Previsto = 4.09, Atingirá o ponto de virada: Não
# Aluno 146: IPV Previsto = 4.02, Atingirá o ponto de virada: Não
# Aluno 147: IPV Previsto = 6.70, Atingirá o ponto de virada: Não
# Aluno 148: IPV Previsto = 4.11, Atingirá o ponto de virada: Não
# Aluno 149: IPV Previsto = 8.06, Atingirá o ponto de virada: Não
# Aluno 150: IPV Previsto = 8.63, Atingirá o ponto de virada: Sim
# Aluno 151: IPV Previsto = 5.43, Atingirá o ponto de virada: Não
# Aluno 152: IPV Previsto = 7.89, Atingirá o ponto de virada: Não
# Aluno 153: IPV Previsto = 8.47, Atingirá o ponto de virada: Não
# Aluno 154: IPV Previsto = 6.05, Atingirá o ponto de virada: Não
# Aluno 155: IPV Previsto = 9.85, Atingirá o ponto de virada: Sim
# Aluno 156: IPV Previsto = 6.93, Atingirá o ponto de virada: Não
# Aluno 157: IPV Previsto = 6.67, Atingirá o ponto de virada: Não
# Aluno 158: IPV Previsto = 7.33, Atingirá o ponto de virada: Não
# Aluno 159: IPV Previsto = 8.25, Atingirá o ponto de virada: Não
# Aluno 160: IPV Previsto = 7.61, Atingirá o ponto de virada: Não
# Aluno 161: IPV Previsto = 7.22, Atingirá o ponto de virada: Não
# Aluno 162: IPV Previsto = 7.22, Atingirá o ponto de virada: Não
# Aluno 163: IPV Previsto = 7.67, Atingirá o ponto de virada: Não
# Aluno 164: IPV Previsto = 6.37, Atingirá o ponto de virada: Não
# Aluno 165: IPV Previsto = 7.00, Atingirá o ponto de virada: Não
# Aluno 166: IPV Previsto = 8.62, Atingirá o ponto de virada: Sim
# Aluno 167: IPV Previsto = 5.54, Atingirá o ponto de virada: Não
# Aluno 168: IPV Previsto = 7.94, Atingirá o ponto de virada: Não
# Aluno 169: IPV Previsto = 7.50, Atingirá o ponto de virada: Não
# Aluno 170: IPV Previsto = 5.80, Atingirá o ponto de virada: Não
# Aluno 171: IPV Previsto = 8.39, Atingirá o ponto de virada: Não
# Aluno 172: IPV Previsto = 7.78, Atingirá o ponto de virada: Não
# Aluno 173: IPV Previsto = 9.29, Atingirá o ponto de virada: Sim
# Aluno 174: IPV Previsto = 7.42, Atingirá o ponto de virada: Não
# Aluno 175: IPV Previsto = 4.93, Atingirá o ponto de virada: Não
# Aluno 176: IPV Previsto = 6.29, Atingirá o ponto de virada: Não
# Aluno 177: IPV Previsto = 6.40, Atingirá o ponto de virada: Não
# Aluno 178: IPV Previsto = 6.29, Atingirá o ponto de virada: Não
# Aluno 179: IPV Previsto = 6.00, Atingirá o ponto de virada: Não
# Aluno 180: IPV Previsto = 7.28, Atingirá o ponto de virada: Não
# Aluno 181: IPV Previsto = 9.32, Atingirá o ponto de virada: Sim
# Aluno 182: IPV Previsto = 8.06, Atingirá o ponto de virada: Não
# Aluno 183: IPV Previsto = 8.25, Atingirá o ponto de virada: Não
# Aluno 184: IPV Previsto = 5.95, Atingirá o ponto de virada: Não
# Aluno 185: IPV Previsto = 8.12, Atingirá o ponto de virada: Não
# Aluno 186: IPV Previsto = 6.50, Atingirá o ponto de virada: Não
# Aluno 187: IPV Previsto = 9.64, Atingirá o ponto de virada: Sim
# Aluno 188: IPV Previsto = 7.50, Atingirá o ponto de virada: Não
# Aluno 189: IPV Previsto = 6.83, Atingirá o ponto de virada: Não
# Aluno 190: IPV Previsto = 8.00, Atingirá o ponto de virada: Não
# Aluno 191: IPV Previsto = 7.88, Atingirá o ponto de virada: Não
# Aluno 192: IPV Previsto = 8.22, Atingirá o ponto de virada: Não
# Aluno 193: IPV Previsto = 5.89, Atingirá o ponto de virada: Não
# Aluno 194: IPV Previsto = 4.91, Atingirá o ponto de virada: Não
# Aluno 195: IPV Previsto = 7.28, Atingirá o ponto de virada: Não
# Aluno 196: IPV Previsto = 5.91, Atingirá o ponto de virada: Não
# Aluno 197: IPV Previsto = 8.13, Atingirá o ponto de virada: Não
# Aluno 198: IPV Previsto = 6.01, Atingirá o ponto de virada: Não
# Aluno 199: IPV Previsto = 6.00, Atingirá o ponto de virada: Não
# Aluno 200: IPV Previsto = 7.08, Atingirá o ponto de virada: Não
# Aluno 201: IPV Previsto = 5.39, Atingirá o ponto de virada: Não
# Aluno 202: IPV Previsto = 7.17, Atingirá o ponto de virada: Não
# Aluno 203: IPV Previsto = 7.67, Atingirá o ponto de virada: Não
# Aluno 204: IPV Previsto = 5.53, Atingirá o ponto de virada: Não
# Aluno 205: IPV Previsto = 8.28, Atingirá o ponto de virada: Não
# Aluno 206: IPV Previsto = 7.33, Atingirá o ponto de virada: Não
# Aluno 207: IPV Previsto = 8.39, Atingirá o ponto de virada: Não
# Aluno 208: IPV Previsto = 9.33, Atingirá o ponto de virada: Sim
# Aluno 209: IPV Previsto = 5.16, Atingirá o ponto de virada: Não
# Aluno 210: IPV Previsto = 5.22, Atingirá o ponto de virada: Não
# Aluno 211: IPV Previsto = 6.89, Atingirá o ponto de virada: Não
# Aluno 212: IPV Previsto = 7.50, Atingirá o ponto de virada: Não
# Aluno 213: IPV Previsto = 7.75, Atingirá o ponto de virada: Não
# Aluno 214: IPV Previsto = 8.21, Atingirá o ponto de virada: Não
# Aluno 215: IPV Previsto = 7.72, Atingirá o ponto de virada: Não
# Aluno 216: IPV Previsto = 6.38, Atingirá o ponto de virada: Não
# Aluno 217: IPV Previsto = 6.12, Atingirá o ponto de virada: Não
# Aluno 218: IPV Previsto = 9.67, Atingirá o ponto de virada: Sim
# Aluno 219: IPV Previsto = 6.37, Atingirá o ponto de virada: Não
# Aluno 220: IPV Previsto = 6.71, Atingirá o ponto de virada: Não
# Aluno 221: IPV Previsto = 8.07, Atingirá o ponto de virada: Não
# Aluno 222: IPV Previsto = 6.71, Atingirá o ponto de virada: Não
# Aluno 223: IPV Previsto = 7.50, Atingirá o ponto de virada: Não
# Aluno 224: IPV Previsto = 9.90, Atingirá o ponto de virada: Sim
# Aluno 225: IPV Previsto = 8.17, Atingirá o ponto de virada: Não
# Aluno 226: IPV Previsto = 6.92, Atingirá o ponto de virada: Não
# Aluno 227: IPV Previsto = 6.12, Atingirá o ponto de virada: Não
# Aluno 228: IPV Previsto = 4.65, Atingirá o ponto de virada: Não
# Aluno 229: IPV Previsto = 7.42, Atingirá o ponto de virada: Não
# Aluno 230: IPV Previsto = 8.39, Atingirá o ponto de virada: Não
# Aluno 231: IPV Previsto = 6.76, Atingirá o ponto de virada: Não
# Aluno 232: IPV Previsto = 8.00, Atingirá o ponto de virada: Não
# Aluno 233: IPV Previsto = 7.88, Atingirá o ponto de virada: Não
# Aluno 234: IPV Previsto = 7.42, Atingirá o ponto de virada: Não
# Aluno 235: IPV Previsto = 5.77, Atingirá o ponto de virada: Não
# Aluno 236: IPV Previsto = 7.17, Atingirá o ponto de virada: Não
# Aluno 237: IPV Previsto = 7.56, Atingirá o ponto de virada: Não
# Aluno 238: IPV Previsto = 7.28, Atingirá o ponto de virada: Não
# Aluno 239: IPV Previsto = 6.49, Atingirá o ponto de virada: Não
# Aluno 240: IPV Previsto = 7.61, Atingirá o ponto de virada: Não
# Aluno 241: IPV Previsto = 8.70, Atingirá o ponto de virada: Sim
# Aluno 242: IPV Previsto = 7.95, Atingirá o ponto de virada: Não
# Aluno 243: IPV Previsto = 8.32, Atingirá o ponto de virada: Não
# Aluno 244: IPV Previsto = 7.50, Atingirá o ponto de virada: Não
# Aluno 245: IPV Previsto = 7.28, Atingirá o ponto de virada: Não
# Aluno 246: IPV Previsto = 8.92, Atingirá o ponto de virada: Sim
# Aluno 247: IPV Previsto = 8.07, Atingirá o ponto de virada: Não
# Aluno 248: IPV Previsto = 7.17, Atingirá o ponto de virada: Não
# Aluno 249: IPV Previsto = 5.73, Atingirá o ponto de virada: Não
# Aluno 250: IPV Previsto = 7.92, Atingirá o ponto de virada: Não
# Aluno 251: IPV Previsto = 7.50, Atingirá o ponto de virada: Não
# Aluno 252: IPV Previsto = 7.33, Atingirá o ponto de virada: Não
# Aluno 253: IPV Previsto = 7.05, Atingirá o ponto de virada: Não
# Aluno 254: IPV Previsto = 8.33, Atingirá o ponto de virada: Não
# Aluno 255: IPV Previsto = 5.18, Atingirá o ponto de virada: Não
# Aluno 256: IPV Previsto = 4.81, Atingirá o ponto de virada: Não
# Aluno 257: IPV Previsto = 8.46, Atingirá o ponto de virada: Não
# Aluno 258: IPV Previsto = 5.83, Atingirá o ponto de virada: Não
# Aluno 259: IPV Previsto = 5.89, Atingirá o ponto de virada: Não
# Aluno 260: IPV Previsto = 5.83, Atingirá o ponto de virada: Não
# Aluno 261: IPV Previsto = 6.00, Atingirá o ponto de virada: Não
# Aluno 262: IPV Previsto = 8.06, Atingirá o ponto de virada: Não
# Aluno 263: IPV Previsto = 8.06, Atingirá o ponto de virada: Não
# Aluno 264: IPV Previsto = 6.31, Atingirá o ponto de virada: Não
# Aluno 265: IPV Previsto = 7.89, Atingirá o ponto de virada: Não
# Aluno 266: IPV Previsto = 7.50, Atingirá o ponto de virada: Não
# Aluno 267: IPV Previsto = 9.26, Atingirá o ponto de virada: Sim
# Aluno 268: IPV Previsto = 7.33, Atingirá o ponto de virada: Não
# Aluno 269: IPV Previsto = 9.43, Atingirá o ponto de virada: Sim
# Aluno 270: IPV Previsto = 8.20, Atingirá o ponto de virada: Não
# Aluno 271: IPV Previsto = 8.25, Atingirá o ponto de virada: Não
# Aluno 272: IPV Previsto = 4.90, Atingirá o ponto de virada: Não
# Aluno 273: IPV Previsto = 8.25, Atingirá o ponto de virada: Não
# Aluno 274: IPV Previsto = 6.16, Atingirá o ponto de virada: Não
# Aluno 275: IPV Previsto = 8.93, Atingirá o ponto de virada: Sim
# Aluno 276: IPV Previsto = 7.22, Atingirá o ponto de virada: Não
# Aluno 277: IPV Previsto = 7.79, Atingirá o ponto de virada: Não
# Aluno 278: IPV Previsto = 7.56, Atingirá o ponto de virada: Não
# Aluno 279: IPV Previsto = 7.33, Atingirá o ponto de virada: Não
# Aluno 280: IPV Previsto = 6.83, Atingirá o ponto de virada: Não
# Aluno 281: IPV Previsto = 9.51, Atingirá o ponto de virada: Sim
# Aluno 282: IPV Previsto = 5.23, Atingirá o ponto de virada: Não
# Aluno 283: IPV Previsto = 9.80, Atingirá o ponto de virada: Sim
# Aluno 284: IPV Previsto = 7.33, Atingirá o ponto de virada: Não
# Aluno 285: IPV Previsto = 6.16, Atingirá o ponto de virada: Não
# Aluno 286: IPV Previsto = 8.28, Atingirá o ponto de virada: Não
# Aluno 287: IPV Previsto = 8.67, Atingirá o ponto de virada: Sim
# Aluno 288: IPV Previsto = 8.00, Atingirá o ponto de virada: Não
# Aluno 289: IPV Previsto = 8.83, Atingirá o ponto de virada: Sim
# Aluno 290: IPV Previsto = 8.50, Atingirá o ponto de virada: Sim
# Aluno 291: IPV Previsto = 5.59, Atingirá o ponto de virada: Não
# Aluno 292: IPV Previsto = 5.59, Atingirá o ponto de virada: Não
# Aluno 293: IPV Previsto = 7.50, Atingirá o ponto de virada: Não
# Aluno 294: IPV Previsto = 7.17, Atingirá o ponto de virada: Não
# Aluno 295: IPV Previsto = 4.45, Atingirá o ponto de virada: Não
# Aluno 296: IPV Previsto = 7.56, Atingirá o ponto de virada: Não
# Aluno 297: IPV Previsto = 3.99, Atingirá o ponto de virada: Não
# Aluno 298: IPV Previsto = 6.04, Atingirá o ponto de virada: Não
# Aluno 299: IPV Previsto = 7.55, Atingirá o ponto de virada: Não
# Aluno 300: IPV Previsto = 7.28, Atingirá o ponto de virada: Não
# Aluno 301: IPV Previsto = 7.50, Atingirá o ponto de virada: Não
# Aluno 302: IPV Previsto = 7.67, Atingirá o ponto de virada: Não
# Aluno 303: IPV Previsto = 7.06, Atingirá o ponto de virada: Não
# Aluno 304: IPV Previsto = 8.22, Atingirá o ponto de virada: Não
# Aluno 305: IPV Previsto = 6.57, Atingirá o ponto de virada: Não
# Aluno 306: IPV Previsto = 6.61, Atingirá o ponto de virada: Não
# Aluno 307: IPV Previsto = 8.50, Atingirá o ponto de virada: Sim
# Aluno 308: IPV Previsto = 7.33, Atingirá o ponto de virada: Não
# Aluno 309: IPV Previsto = 7.22, Atingirá o ponto de virada: Não
# Aluno 310: IPV Previsto = 7.06, Atingirá o ponto de virada: Não
# Aluno 311: IPV Previsto = 7.22, Atingirá o ponto de virada: Não
# Aluno 312: IPV Previsto = 7.50, Atingirá o ponto de virada: Não
# Aluno 313: IPV Previsto = 7.43, Atingirá o ponto de virada: Não
# Aluno 314: IPV Previsto = 5.83, Atingirá o ponto de virada: Não
# Nota de corte para 2020: 8.80
# Nota de corte para 2021: 9.15
# Nota de corte para 2022: 8.48
# Nota de corte para 2023: 8.47

# %%
resultado_df.to_csv('assets/csv/resultados_previsao_ipv_2023.csv', index=False)

# %%
# Definir estilo dos gráficos
sns.set(style="whitegrid")

# 1. Gráfico de Dispersão dos IPV Previsto vs. Notas de Corte
plt.figure(figsize=(10, 6))
plt.scatter(range(len(ipvs_previstos_2023)), ipvs_previstos_2023, label='IPV Previsto 2023', color='blue', alpha=0.6)
plt.axhline(y=nota_corte_2023, color='red', linestyle='--', label='Nota de Corte 2023')
plt.title('IPV Previsto para 2023 vs Nota de Corte')
plt.xlabel('Alunos')
plt.ylabel('IPV Previsto')
plt.legend()
plt.show()

# 2. Histograma dos IPV Previsto
plt.figure(figsize=(10, 6))
sns.histplot(ipvs_previstos_2023, bins=10, kde=True)
plt.axvline(x=nota_corte_2023, color='red', linestyle='--', label='Nota de Corte 2023')
plt.title('Distribuição do IPV Previsto para 2023')
plt.xlabel('IPV Previsto')
plt.ylabel('Frequência')
plt.legend()
plt.show()

# 3. Gráfico de Linhas para Comparar Médias e Notas de Corte
anos = ['2020', '2021', '2022', '2023']
medias = [media_2020, media_2021, media_2022, media_2023]
notas_corte = [nota_corte_2020, nota_corte_2021, nota_corte_2022, nota_corte_2023]

plt.figure(figsize=(10, 6))
plt.plot(anos, medias, marker='o', label='Média dos IPV', color='blue')
plt.plot(anos, notas_corte, marker='o', label='Nota de Corte', color='red')
plt.title('Média dos IPV e Notas de Corte ao Longo dos Anos')
plt.xlabel('Ano')
plt.ylabel('Valor do IPV')
plt.legend()
plt.show()

# %%
# Calcular porcentagens para cada ano
anos = ['2020', '2021', '2022', '2023']
notas_corte = [nota_corte_2020, nota_corte_2021, nota_corte_2022, nota_corte_2023]
ipvs = [df['IPV_2020'], df['IPV_2021'], df['IPV_2022'], ipvs_previstos_2023]

porcentagens_acima_nota_corte = []

for ipv, nota in zip(ipvs, notas_corte):
    total_alunos = len(ipv)
    alunos_acima_nota_corte = sum(i > nota for i in ipv)
    porcentagem_acima_nota_corte = (alunos_acima_nota_corte / total_alunos) * 100
    porcentagens_acima_nota_corte.append(porcentagem_acima_nota_corte)

# Criar o gráfico de barras
plt.figure(figsize=(10, 6))
plt.bar(anos, porcentagens_acima_nota_corte, color=['blue', 'orange', 'green', 'red'], alpha=0.7)
plt.title('Porcentagem de Alunos que Atingiram o IPV Acima da Nota de Corte (2020-2023)')
plt.ylabel('Porcentagem (%)')
plt.ylim(0, 100)

# Adicionar os valores em cima das barras
for i, v in enumerate(porcentagens_acima_nota_corte):
    plt.text(i, v + 1, f"{v:.1f}%", ha='center', fontweight='bold')

plt.show()

# %%
residuos = y_test - model.predict(X_test)
plt.figure(figsize=(10, 6))
plt.scatter(model.predict(X_test), residuos)
plt.axhline(0, color='red', linestyle='--')
plt.title('Gráfico de Resíduos')
plt.xlabel('Previsões')
plt.ylabel('Resíduos')
plt.show()

# %%
mse = mean_squared_error(y_test, model.predict(X_test))
print(f"Erro Quadrático Médio (MSE): {mse:.2f}")

rmse = mse ** 0.5
print(f"Raiz do Erro Quadrático Médio (RMSE): {rmse:.2f}")

mae = mean_absolute_error(y_test, model.predict(X_test))
print(f"Erro Absoluto Médio (MAE): {mae:.2f}")

r2 = r2_score(y_test, model.predict(X_test))
print(f"Coeficiente de Determinação (R²): {r2:.2f}")
# Out:
# Erro Quadrático Médio (MSE): 0.00
# Raiz do Erro Quadrático Médio (RMSE): 0.07
# Erro Absoluto Médio (MAE): 0.03
# Coeficiente de Determinação (R²): 1.00

# %%
# Verificar se os alunos não atingiram o ponto de virada nos anos anteriores
nunca_atenderam = (df['PONTO_VIRADA_2020'] == 'Não') & (df['PONTO_VIRADA_2021'] == 'Não') & (df['PONTO_VIRADA_2022'] == 'Não')

# Criar uma série para PONTO_VIRADA_2023 a partir das previsões
ponto_virada_2023 = ['Sim' if ipv > nota_corte_2023 else 'Não' for ipv in ipvs_previstos_2023]

# Criar um DataFrame temporário para comparação
df['PONTO_VIRADA_2023'] = ponto_virada_2023  # Adicionando a coluna ao DataFrame

# Encontrar os alunos que atingiram o ponto de virada em 2023
atingiram_2023 = df['PONTO_VIRADA_2023'] == 'Sim'

# Identificar os índices dos alunos que nunca atingiram e que atingiram em 2023
alunos_atingiram_2023 = df[nunca_atenderam & atingiram_2023]

# Exibir os resultados
if not alunos_atingiram_2023.empty:
    print("Alunos que nunca atingiram o ponto de virada em 2020, 2021 e 2022, mas atingiram em 2023:")
    print(alunos_atingiram_2023[['ID_Aluno', 'PONTO_VIRADA_2023']])  # Ajuste para as colunas que deseja mostrar
else:
    print("Nenhum aluno que nunca atingiu o ponto de virada em 2020, 2021 e 2022 atingiu em 2023.")
# Out:
# Nenhum aluno que nunca atingiu o ponto de virada em 2020, 2021 e 2022 atingiu em 2023.
